# %% [markdown]
# <a href="https://colab.research.google.com/github/ErisonBarros/Analise-Exploratria-Setores-Censitarios/blob/master/Paginas_da_Disciplinas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Projeto de Parcelamento Territorial

# %% [markdown]
# Segue a Lista
# *   Item 1
# *   Item 2
